# %% [markdown]
# """
# {
#   "cells": [
#     {
#       "cell_type": "markdown",
#       "metadata": {},
#       "source": [
#         "# MSME Agent Platform - Interactive Analysis\n",
#         "This notebook demonstrates how to use the platform for data analysis."
#       ]
#     },
#     {
#       "cell_type": "code",
#       "execution_count": null,
#       "metadata": {},
#       "source": [
#         "from basic_usage import MSMEPlatformClient\n",
#         "import pandas as pd\n",
#         "import plotly.express as px\n",
#         "\n",
#         "# Initialize client\n",
#         "client = MSMEPlatformClient()\n",
#         "print(client.health_check())"
#       ]
#     },
#     {
#       "cell_type": "code",
#       "execution_count": null,
#       "metadata": {},
#       "source": [
#         "# Upload your dataset\n",
#         "result = client.upload_dataset('your_data.csv')\n",
#         "dataset_id = result['dataset_id']\n",
#         "print(f\"Dataset uploaded: {dataset_id}\")\n",
#         "print(f\"Columns: {result['columns']}\")"
#       ]
#     },
#     {
#       "cell_type": "code",
#       "execution_count": null,
#       "metadata": {},
#       "source": [
#         "# Ask questions in natural language\n",
#         "response = client.query(\n",
#         "    query=\"What are the revenue trends over time?\",\n",
#         "    user_id=\"analyst_1\",\n",
#         "    context={\"dataset_id\": dataset_id}\n",
#         ")\n",
#         "\n",
#         "# Display results\n",
#         "for agent_resp in response['agent_responses']:\n",
#         "    if agent_resp['success']:\n",
#         "        print(f\"\\n{agent_resp['agent']}:\")\n",
#         "        print(agent_resp['data'])"
#       ]
#     },
#     {
#       "cell_type": "code",
#       "execution_count": null,
#       "metadata": {},
#       "source": [
#         "# Visualize results\n",
#         "# (Example: plot trends if data is available)\n",
#         "fig = px.line(data_frame, x='date', y='revenue', title='Revenue Trends')\n",
#         "fig.show()"
#       ]
#     }
#   ]
# }
# """
